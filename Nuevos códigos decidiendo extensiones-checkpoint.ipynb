# %%
#Ahora haremos el mismo código de antes solo que comprobando si el código dual correspondiente a cada código es también AMDS, haciendo al código original NMDS


#Derivada de Hasse-Schmidt

def HasseSchmidtDer(n,y,t):
    return binomial(n,t)*y^(n-t)

#El vector a extender en cualquier punto, salvo el infinito, usando el programa anterior

def vectorextension(k,y,t):
    return [[HasseSchmidtDer(n,y,t)] for n in range(k)]

#El vector a extender en el punto del infinito, este tiene que ser hecho por separado, ya que no es sencillo programar un cambio de coordenadas en SAGE.

def vectorextensioninf(k,t):
    return [[kronecker_delta(k-n-1,t)] for n in range(k)]

def posibles_extensiones_a(q,k,a):
    for j in range(1,k):
        s.append([a,j])
    t=[Combinations(s,1).list()]
    for i in range(2,k):
        t.append(Combinations(s*i,i).list())
    return flatten(t,max_level=1)

def matrix_to_latex(matrix):
    """
    Converts a given 2D list (matrix) to LaTeX matrix format.
    
    Parameters:
    matrix (list of list of numbers): The matrix to be converted.
    
    Returns:
    str: A string containing the LaTeX code for the matrix.
    """
    latex_matrix = "\\begin{bmatrix}\n"
    rows = [" & ".join(map(str, row)) for row in matrix]
    latex_matrix += " \\\\\n".join(rows)
    latex_matrix += "\n\\end{bmatrix}"
    return latex_matrix


#Sabiendo que funciona ahora hacemos un programa que determine los códigos AMDS y qué extensiones funcionan (trivialmente las que solo extienden por una columna son AMDS)

def extensiones_totales_a(q,k,a):


    #Definimos la longitud de la lista de extensiones, una nueva tabla S el cuerpo Fq y su generador al que llamaremos x
    T=[]
    S=[]
    SS=[]
    F=GF(q)
    x=F.gen()

    #Acto seguido definimos la matriz generadora de los códigos generalized Reed-Solomon añadiendo la columna de infinito

    G = codes.GeneralizedReedSolomonCode(F.list(),k)
    G = G.generator_matrix()

    row = vectorextensioninf(k,0)
    row = matrix(F,row)
    G = G.augment(row)

    #Definimos G_estable=G para poder reescribarla luego

    G_estable=G

    #Después extendemos matrices utilizando las indicaciones de la lista t (si los elementos de t son enteros entre 1 y q-1 entonces se aplica       la extension por la derivada que aparece en el segundo término, en caso contrario se deriva por el infinito)
    #Esto nos quiere decir que t tiene que ser de la forma t=[[1,2],[3,5],[-1,4],...]

    s=[]
    for j in range(1,k):
        s.append([a,j])
    for j in range(1,k):
        print(j)
        T=Combinations(s,j).list()
        for i in range(len(T)):
            t=T[i]
            for el in t:
                if el[0] in ZZ and 1<=el[0] and el[0]<=q-1:
                    row = vectorextension(k,x^(el[0]),el[1])
                else:
                    row = vectorextensioninf(k,el[1])
                row = matrix(F,row)
                G = G.augment(row)

        #Terminamos calculando los datos del código generado por la nueva matriz G

            C=codes.LinearCode(G)
            C_dual=C.dual_code()

            d=C.minimum_distance()
            d_dual=C_dual.minimum_distance()
            n=C.length()
            k=C.dimension()
            v=n-k-d+1
            v_dual=k-d_dual+1

        #Si el código es AMDS lo incluímos en la lista final, y después cambiamos la matrix G por G_estable que definimos antes

            S.append([n,k,d,q,t])
            G=G_estable
            if 1<=a and a<=q-1:
                f=open('extensiones_en_' + str(x**a) +'_' + str([q,k]),'a')
            else:
                f=open('extensiones_en_' + 'infty' +'_' + str([q,k]),'a')
            
            f.write('Valores: \n')
            f.write(str([n,k,d,q,t]))
            f.write('\n')
            f.write('Matriz generadora: \n')
            f.write(str(C.generator_matrix()))
            if v==v_dual and v==1 and j>k-2:
                print(matrix_to_latex(C.generator_matrix()))
            f.write('\n')
            f.write('Polinomio enumerador: \n')
            f.write(str(C.weight_enumerator()))
            f.write('\n')
            f.write('Es un código A^' + str(v) +'MDS\n\n')
            f.write('Valores duales: \n')
            f.write(str([n,n-k,d_dual,q]))
            f.write('\n')
            f.write('Matriz dual: \n')
            f.write(str(C_dual.generator_matrix()))
            f.write('\n')
            f.write('Polinomio dual: \n')
            f.write(str(C_dual.weight_enumerator()))
            f.write('\n')
            f.write('Su dual es un código A^' + str(v_dual) +'MDS\n\n')
            if v==v_dual:
                f.write('Lo que lo hace un código N^' + str(v_dual) +'MDS\n\n')
            f.write('================================================\n')
            f.write('================================================\n')
            f.write('================================================\n\n')
    
    
            f.close()
    print('Done!')

#Probamos el código

extensiones_totales_a(11,6,11)
# Out:
# 1
# 2
# 3
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/misc/cachefunc.pyx in sage.misc.cachefunc.CachedMethodCaller.__call__ (build/cythonized/sage/misc/cachefunc.c:10303)()
#    1942             try:
# -> 1943                 return cache[k]
#    1944             except TypeError:  # k is not hashable
#
# KeyError: ((None,), ())
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/gap.py in _eval_line(self, line, allow_use_file, wait_for_prompt, restart_if_needed)
#     747             (normal, error) = self._execute_line(line, wait_for_prompt=wait_for_prompt,
# --> 748                                                  expect_eof=expect_eof)
#     749
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/gap.py in _execute_line(self, line, wait_for_prompt, expect_eof)
#     612             while True:
# --> 613                 x = E.expect_list(self._compiled_full_pattern)
#     614                 current_outputs.append(E.before)
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/pexpect/spawnbase.py in expect_list(self, pattern_list, timeout, searchwindowsize, async_, **kw)
#     371         else:
# --> 372             return exp.expect_loop(timeout)
#     373
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/pexpect/expect.py in expect_loop(self, timeout)
#     168                 # Still have time left, so read more data
# --> 169                 incoming = spawn.read_nonblocking(spawn.maxread, timeout)
#     170                 if self.spawn.delayafterread is not None:
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/pexpect/pty_spawn.py in read_nonblocking(self, size, timeout)
#     499         # (possibly timeout=None), we call select() with a timeout.
# --> 500         if (timeout != 0) and select(timeout):
#     501             return super(spawn, self).read_nonblocking(size)
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/pexpect/pty_spawn.py in select(timeout)
#     449             def select(timeout):
# --> 450                 return select_ignore_interrupts([self.child_fd], [], [], timeout)[0]
#     451
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/pexpect/utils.py in select_ignore_interrupts(iwtd, owtd, ewtd, timeout)
#     142         try:
# --> 143             return select.select(iwtd, owtd, ewtd, timeout)
#     144         except InterruptedError:
#
# src/cysignals/signals.pyx in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-06b44312a0b4> in <module>
#     141 #Probamos el código
#     142
# --> 143 extensiones_totales_a(Integer(11),Integer(6),Integer(11))
#
# <ipython-input-10-06b44312a0b4> in extensiones_totales_a(q, k, a)
#      92
#      93             d=C.minimum_distance()
# ---> 94             d_dual=C_dual.minimum_distance()
#      95             n=C.length()
#      96             k=C.dimension()
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/misc/cachefunc.pyx in sage.misc.cachefunc.CachedMethodCaller.__call__ (build/cythonized/sage/misc/cachefunc.c:10437)()
#    1946                 return cache[k]
#    1947         except KeyError:
# -> 1948             w = self._instance_call(*args, **kwds)
#    1949             cache[k] = w
#    1950             return w
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/misc/cachefunc.pyx in sage.misc.cachefunc.CachedMethodCaller._instance_call (build/cythonized/sage/misc/cachefunc.c:9916)()
#    1822             True
#    1823         """
# -> 1824         return self.f(self._instance, *args, **kwds)
#    1825
#    1826     cdef fix_args_kwds(self, tuple args, dict kwds):
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/coding/linear_code.py in minimum_distance(self, algorithm)
#    1399             d = C.MinimumWeight()
#    1400             return ZZ(d)
# -> 1401         return self._minimum_weight_codeword(algorithm).hamming_weight()
#    1402
#    1403     def _minimum_weight_codeword(self, algorithm = None):
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/coding/linear_code.py in _minimum_weight_codeword(self, algorithm)
#    1462         gap.eval('v:=Z({})*{}'.format(q,[0]*n))
#    1463         for i in range(1,k+1):
# -> 1464             gap.eval("P:=AClosestVectorCombinationsMatFFEVecFFECoords(Gmat,K,v,{},1)".format(i))
#    1465             gap.eval("d:=WeightVecFFE(P[1])")
#    1466             v = gap("P[1]")
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/gap.py in eval(self, x, newlines, strip, split_lines, **kwds)
#     585             if not input_line.endswith(';'):
#     586                 input_line += ';'
# --> 587         result = Expect.eval(self, input_line, **kwds)
#     588         if not newlines:
#     589             result = result.replace("\\\n","")
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/expect.py in eval(self, code, strip, synchronize, locals, allow_use_file, split_lines, **kwds)
#    1380                 elif split_lines:
#    1381                     return '\n'.join([self._eval_line(L, allow_use_file=allow_use_file, **kwds)
# -> 1382                                         for L in code.split('\n') if L != ''])
#    1383                 else:
#    1384                     return self._eval_line(code, allow_use_file=allow_use_file, **kwds)
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/expect.py in <listcomp>(.0)
#    1380                 elif split_lines:
#    1381                     return '\n'.join([self._eval_line(L, allow_use_file=allow_use_file, **kwds)
# -> 1382                                         for L in code.split('\n') if L != ''])
#    1383                 else:
#    1384                     return self._eval_line(code, allow_use_file=allow_use_file, **kwds)
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/gap.py in _eval_line(self, line, allow_use_file, wait_for_prompt, restart_if_needed)
#     797
#     798         except KeyboardInterrupt:
# --> 799             self._keyboard_interrupt()
#     800             raise KeyboardInterrupt("Ctrl-c pressed while running %s"%self)
#     801
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/gap.py in _keyboard_interrupt(self)
#     675         """
#     676         self.quit()
# --> 677         raise KeyboardInterrupt("Ctrl-c pressed while running %s"%self)
#     678
#     679     def _eval_line(self, line, allow_use_file=True, wait_for_prompt=True, restart_if_needed=True):
#
# KeyboardInterrupt: Ctrl-c pressed while running Gap
